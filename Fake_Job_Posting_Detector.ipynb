# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-969c7550-957e-49d7-a37d-e3b9445e04d3" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-969c7550-957e-49d7-a37d-e3b9445e04d3">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd

# Load the uploaded CSV
df = pd.read_csv("minidatasetsame.csv")

# Show first few rows
df.head()
# Out:
# ---------------------------------------------------------------------------
# UnicodeDecodeError                        Traceback (most recent call last)
# /tmp/ipython-input-3-3812274660.py in <cell line: 0>()
#       2
#       3 # Load the uploaded CSV
# ----> 4 df = pd.read_csv("minidatasetsame.csv")
#       5
#       6 # Show first few rows
#
# ...

# %%
df = pd.read_csv("minidatasetsame.csv", encoding='ISO-8859-1')
df.head()
# Out:
#                            job_title  location  industry  salary_range  \
# 0        frontendjavascript engineer      1304       545           NaN
# 1             primary school teacher      1902       649  34993-135552
# 2                       webcam model      4726      1383           NaN
# 3                 forensic scientist      1521      1052  62233-140688
# 4  account sales managers 80130000yr      3186      1383           NaN
#
#                                      company_profile  \
# 0                                                NaN
# 1                         bush ltd  established 1991
# 2                                                NaN
# 3                     castilloward  established 2004
# 4  we have aggressive growth plans in place for t...
#
#                                             job_desc  \
# 0  workable is a productdriven software company w...
# 1  exist goal where travel earn 5000week immediat...
# ...

# %%
df.isnull().sum()
# Out:
# job_title             0
# location              0
# industry              0
# salary_range       6331
# company_profile    1859
# job_desc              3
# skills_desc        1041
# employment_type    1225
# fraudulent            0
# text                  0
# dtype: int64

# %%
# Fill missing text fields with empty strings
df['job_desc'] = df['job_desc'].fillna('')
df['skills_desc'] = df['skills_desc'].fillna('')

# Combine both into a single text field
df['text'] = df['job_desc'] + ' ' + df['skills_desc']

# %%
X = df['text']
y = df['fraudulent']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

tfidf = TfidfVectorizer(stop_words='english', max_features=5000)
X_tfidf = tfidf.fit_transform(X)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_tfidf, y, test_size=0.2, random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

model = LogisticRegression()
model.fit(X_train, y_train)
# Out:
# LogisticRegression()

# %%
from sklearn.metrics import classification_report, accuracy_score

y_pred = model.predict(X_test)

print("Accuracy:", accuracy_score(y_test, y_pred))
print("\nClassification Report:\n", classification_report(y_test, y_pred))
# Out:
# Accuracy: 0.9520440251572327
#
# Classification Report:
#                precision    recall  f1-score   support
#
#            0       0.92      0.99      0.95      1248
#            1       0.99      0.91      0.95      1296
#
#     accuracy                           0.95      2544
#    macro avg       0.95      0.95      0.95      2544
# weighted avg       0.96      0.95      0.95      2544

# %%
import pickle

# Save model
with open("model.pkl", "wb") as f:
    pickle.dump(model, f)

# Save vectorizer
with open("vectorizer.pkl", "wb") as f:
    pickle.dump(tfidf, f)

# %%
from google.colab import files

files.download("model.pkl")
files.download("vectorizer.pkl")

# %%
# !pip install easyocr
# !pip install opencv-python-headless  # required for image processing
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.9/2.9 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.5 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 8.1 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 4.8 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 4.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 4.3 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 3.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 2.2 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 1.6 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 2.4 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 422.8/422.8 kB 2.5 MB/s eta 0:00:00
# ...

# %%
import easyocr
import cv2
import matplotlib.pyplot as plt
from PIL import Image
import numpy as np
from sklearn.linear_model import LogisticRegression
import pickle

# %%
# Load your trained model and vectorizer
model = pickle.load(open("model.pkl", "rb"))
vectorizer = pickle.load(open("vectorizer.pkl", "rb"))

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-21f87411-e5c5-4cd7-9013-d38fd70ec18c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-21f87411-e5c5-4cd7-9013-d38fd70ec18c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
reader = easyocr.Reader(['en'])  # English OCR reader

# Replace with your uploaded image file name
image_path = 'jobdesc1.jpg'

# Extract text
results = reader.readtext(image_path, detail=0)
extracted_text = " ".join(results)

print("Extracted Text:")
print(extracted_text)
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /tmp/ipython-input-19-463692110.py in <cell line: 0>()
#       5
#       6 # Extract text
# ----> 7 results = reader.readtext(image_path, detail=0)
#       8 extracted_text = " ".join(results)
#       9
#
# /usr/local/lib/python3.11/dist-packages/easyocr/easyocr.py in readtext(self, image, decoder, beamWidth, batch_size, workers, allowlist, blocklist, detail, rotation_info, paragraph, min_size, contrast_ths, adjust_contrast, filter_ths, text_threshold, low_text, link_threshold, canvas_size, mag_ratio, slope_ths, ycenter_ths, height_ths, width_ths, y_ths, x_ths, add_margin, threshold, bbox_min_score, bbox_min_size, max_candidates, output_format)
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-969196b3-91f7-4068-922b-1a88a6e2fa67" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-969196b3-91f7-4068-922b-1a88a6e2fa67">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import easyocr

# Step 1: Set correct image path
image_path = "1min.png"  # ✅ your uploaded image file name

# Step 2: Initialize OCR Reader
reader = easyocr.Reader(['en'])

# Step 3: Extract text from image
results = reader.readtext(image_path, detail=0)
extracted_text = " ".join(results)

# Step 4: Display extracted text
print("📄 Extracted Text from Image:")
print(extracted_text)

# Step 5: Predict using your trained ML model
input_vector = vectorizer.transform([extracted_text])
prediction = model.predict(input_vector)[0]

# Step 6: Show result
if prediction == 0:
    print("✅ Prediction: Real Job Posting")
else:
    print("❌ Prediction: Fake Job Posting")
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 📄 Extracted Text from Image:
# ...

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-7d517e55-eb3f-4921-ada8-655895ac9942" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-7d517e55-eb3f-4921-ada8-655895ac9942">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import easyocr

# ✅ Step 1: Set correct image path
image_path = "2min.png"

# ✅ Step 2: Initialize OCR Reader
reader = easyocr.Reader(['en'])

# ✅ Step 3: Extract text from image
results = reader.readtext(image_path, detail=0)
extracted_text = " ".join(results)

# ✅ Step 4: Display extracted text
print("📄 Extracted Text from Image:")
print(extracted_text)

# ✅ Step 5: Predict using your trained ML model
input_vector = vectorizer.transform([extracted_text])
prediction = model.predict(input_vector)[0]

# ✅ Step 6: Show result
if prediction == 0:
    print("✅ Prediction: Real Job Posting")
else:
    print("❌ Prediction: Fake Job Posting")
# Out:
# WARNING:easyocr.easyocr:Neither CUDA nor MPS are available - defaulting to CPU. Note: This module is much faster with a GPU.
# 📄 Extracted Text from Image:
# ...

# %%
import pandas as pd
import pickle

# Load dataset
df = pd.read_csv("minidatasetsame.csv", encoding="latin1")

# Load model and vectorizer
model = pickle.load(open("model.pkl", "rb"))
vectorizer = pickle.load(open("vectorizer.pkl", "rb"))

# Predict on full dataset
X_vect = vectorizer.transform(df['text'])
df['predicted'] = model.predict(X_vect)

# Show 5 fake job postings predicted by the model
fake_jobs = df[df['predicted'] == 1].sample(5, random_state=1)
for i, row in fake_jobs.iterrows():
    print(f"\n--- Fake Job Example {i} ---\n")
    print(row['text'][:1000])  # Limit to 1000 chars for readability
# Out:
# --- Fake Job Example 4280 ---
#
# research scientist life sciences jones and sons  established 2014 air science beat man probably earn 5000week immediate hiring contact now at leemarkgordoncom basic knowledge in clearly no degree required flexible hours
#
# --- Fake Job Example 3486 ---
#
# broadcast presenter green and sons  established 2010 police table lose pressure several serious have earn 5000week immediate hiring contact now at warnermelindagmailcom basic knowledge in sort no degree required flexible hours
#
# --- Fake Job Example 1158 ---
#
# amenity horticulturist knight ltd  established 1997 another turn admit group earn 5000week immediate hiring contact now at jasmine08yahoocom basic knowledge in tend no degree required flexible hours
#
# --- Fake Job Example 2096 ---
#
# ...
